# %%
import numpy as np
from pygltflib import GLTF2, Node
import trimesh
#from trimesh.scene import Scene
import pyrender
import os

# Helper functions for quaternion and matrix operations

def quaternion_to_matrix(q):
    """Convert quaternion [x, y, z, w] to 4x4 rotation matrix."""
    x, y, z, w = q
    xx, yy, zz = x*x, y*y, z*z
    xy, xz, yz = x*y, x*z, y*z
    wx, wy, wz = w*x, w*y, w*z
    
    return np.array([
        [1-2*(yy+zz), 2*(xy-wz),   2*(xz+wy),   0],
        [2*(xy+wz),   1-2*(xx+zz), 2*(yz-wx),   0],
        [2*(xz-wy),   2*(yz+wx),   1-2*(xx+yy), 0],
        [0,           0,           0,           1]
    ], dtype=np.float32)

def compose_matrix(translation, rotation, scale):
    """Compose translation, rotation, scale into a 4x4 matrix."""
    T = np.eye(4, dtype=np.float32)
    if translation:
        T[:3, 3] = translation

    R = quaternion_to_matrix(rotation or [0, 0, 0, 1])

    S = np.eye(4, dtype=np.float32)
    if scale:
        S[0,0], S[1,1], S[2,2] = scale

    return T @ R @ S

def world_to_local_rotation(target_world_rot, parent_world_rot):
    """
    Convert a world-space quaternion into a local-space one given parent world-space rotation.
    
    Both quaternions should be in [x, y, z, w] format.
    """
    r_target = R.from_quat(target_world_rot)
    r_parent = R.from_quat(parent_world_rot)
    
    # Local rotation = inverse(parent_world) * target_world
    r_local = r_parent.inv() * r_target
    return r_local.as_quat()

def direction_vector(p1, p2):
    vec = p2 - p1
    norm = np.linalg.norm(vec)
    return vec / norm if norm > 1e-6 else np.zeros(3)

def quaternion_from_vectors(source, target):
    """
    Compute the quaternion that rotates `source` to align with `target`.
    """
    source = source / np.linalg.norm(source)
    target = target / np.linalg.norm(target)
    rot = R.align_vectors([target], [source])[0]
    return rot.as_quat()

# %%
# SkeletonHelper is the simple version that focuses on setting joint transforms
class SkeletonHelper:
    def __init__(self, gltf: GLTF2, skin_index=0):
        self.gltf = gltf
        self.skin = gltf.skins[skin_index]
        self.joint_nodes = self.skin.joints #TODO refator to remove duplication
        self.node_to_parent = self.build_parent_map()
        self.joint_indices = self.skin.joints
        
        # Will store local and world transforms
        self.local_matrices = {}
        self.world_matrices = {}
        self.inverse_bind_matrices = self.load_inverse_bind_matrices()
        self.final_skinning_matrices = {}
        # Build name -> index mapping
        self.joint_name_to_idx = {}
        for joint_idx in self.joint_indices:
            node = gltf.nodes[joint_idx]
            name = node.name or f"Joint_{joint_idx}"
            self.joint_name_to_idx[name] = joint_idx

        
    def build_parent_map(self):
        """Build a map from node index to its parent node index."""
        node_to_parent = {}
        for idx, node in enumerate(self.gltf.nodes):
            if node.children:
                for child_idx in node.children:
                    node_to_parent[child_idx] = idx
        return node_to_parent

    def load_inverse_bind_matrices(self):
        """Load inverse bind matrices from skin."""
        accessor_idx = self.skin.inverseBindMatrices
        if accessor_idx is None:
            raise ValueError("Skin has no inverseBindMatrices accessor!")
        
        accessor = self.gltf.accessors[accessor_idx]
        buffer_view = self.gltf.bufferViews[accessor.bufferView]
        buffer = self.gltf.buffers[buffer_view.buffer]
        
        # Extract raw binary
        raw = self.get_buffer_data()
        
        # Parse matrices
        stride = buffer_view.byteStride or 64  # 4x4 floats = 64 bytes
        inverse_bind_matrices = []
        for i in range(accessor.count):
            offset = buffer_view.byteOffset + accessor.byteOffset + i * stride
            mat = np.frombuffer(raw, dtype=np.float32, count=16, offset=offset)
            mat = mat.reshape((4,4)).T  # glTF is column-major
            inverse_bind_matrices.append(mat)
        
        return inverse_bind_matrices
    
    def get_buffer_data(self, buffer_index=0):
        buffer = self.gltf.buffers[buffer_index]
        uri = buffer.uri

        # Embedded in .glb
        if uri is None:
            return self.gltf.binary_blob()  # Works for .glb files

        # Embedded base64 in .gltf
        if uri.startswith('data:'):
            import base64
            header, encoded = uri.split(',', 1)
            return base64.b64decode(encoded)

        # External .bin file
        else:
            #buffer_path = os.path.join(os.path.dirname(self.gltf), uri)
            buffer_path = "data/ride1/rider_mesh_w_rig.bin"
            with open(buffer_path, 'rb') as f:
                return f.read()
    
    def set_joint_rotation(self, joint_idx, new_quat):
        """
        Set the rotation of a joint by index.

        Args:
            joint_idx (int): The joint's index.
            new_quat (list or np.array): The new quaternion [x, y, z, w].
        """
        if joint_idx not in self.joint_nodes:
            raise ValueError(f"Joint index {joint_idx} not found!")

        node = self.gltf.nodes[joint_idx]

        # Set rotation (overwrite)
        node.rotation = list(new_quat)
        print(f"Set joint {joint_idx} rotation to {new_quat}")
    
    def set_joint_translation(self, joint_idx, new_translation):
        """
        Set the translation of a joint by index.

        Args:
            joint_idx (int): The joint's index.
            new_translation (list or np.array): The new translation [x, y, z].
        """
        if joint_idx not in self.joint_nodes:
            raise ValueError(f"Joint index {joint_idx} not found!")

        node = self.gltf.nodes[joint_idx]

        # Set translation (overwrite)
        node.translation = list(new_translation)
        print(f"Set joint {joint_idx} translation to {new_translation}")
    
    def set_joint_world_rotation(self, joint_idx, new_quat):
        """
        Set the rotation of a joint by index.

        Args:
            joint_idx (int): The joint's index.
            new_quat (list or np.array): The new quaternion [x, y, z, w].
        """
        if joint_idx not in self.joint_nodes:
            raise ValueError(f"Joint index {joint_idx} not found!")

        node = self.gltf.nodes[joint_idx]

        # Set rotation (overwrite)
        node.rotation = list(world_to_local_rotation(new_quat, node.rotation))
        print(f"Set joint {joint_idx} rotation to {new_quat}")
    
    def set_joint_world_translation(self, joint_idx, new_translation):
        """
        Set the translation of a joint by index.

        Args:
            joint_idx (int): The joint's index.
            new_translation (list or np.array): The new translation [x, y, z].
        """
        if joint_idx not in self.joint_nodes:
            raise ValueError(f"Joint index {joint_idx} not found!")

        node = self.gltf.nodes[joint_idx]

        # Set translation (overwrite)
        node.translation = list(new_translation)
        print(f"Set joint {joint_idx} translation to {new_translation}")    

    def set_joint_rotation_by_name(self, joint_name, new_quat, as_world=False):
        """
        Set the rotation of a joint by name.

        Args:
            joint_name (str): The joint's name.
            new_quat (list or np.array): The new quaternion [x, y, z, w].
        """
        if joint_name not in self.joint_name_to_idx:
            raise ValueError(f"Joint name {joint_name} not found!")

        idx = self.joint_name_to_idx[joint_name]
        if as_world:
            self.set_joint_world_rotation(idx, new_quat)
        else:
            self.set_joint_rotation(idx, new_quat)

    def set_joint_translation_by_name(self, joint_name, new_translation):
        """
        Set the translation of a joint by name.

        Args:
            joint_name (str): The joint's name.
            new_translation (list or np.array): The new translation [x, y, z].
        """
        if joint_name not in self.joint_name_to_idx:
            raise ValueError(f"Joint name {joint_name} not found!")

        idx = self.joint_name_to_idx[joint_name]
        self.set_joint_translation(idx, new_translation)
    
    def apply_pose(self, pose_points, point_names, bones):
        """
        Apply a full pose update.
        """
        #point_names = GetKeypointNames()
        #bones = GetBones()
        #self #skel = SkeletonHelperGLTF.SkeletonHelper(mesh)
        for bone_name, (kp_start, kp_end) in bones.items(): #TODO: bones should be iterated in tree order
            source_dir = np.array([0, -1, 0])  # assume bone initially points down local Y axis
            target_dir = direction_vector(pose_points[point_names[kp_start]], pose_points[point_names[kp_end]])
            quat = quaternion_from_vectors(source_dir, target_dir)  # x, y, z, w
            self.set_joint_rotation_by_name(bone_name, quat, as_world=True)
        self.update()
    
    def compute_local_matrices(self):
        """Compute local transform matrices for each joint."""
        for node_idx in self.joint_nodes:
            node = self.gltf.nodes[node_idx]
            translation = node.translation if node.translation else [0, 0, 0]
            rotation = node.rotation if node.rotation else [0, 0, 0, 1]
            scale = node.scale if node.scale else [1, 1, 1]
            
            self.local_matrices[node_idx] = compose_matrix(translation, rotation, scale)
    
    def compute_world_matrices(self):
        """Compute world transform matrices hierarchically."""
        def get_world_matrix(node_idx):
            if node_idx in self.world_matrices:
                return self.world_matrices[node_idx]
            try:
                local = self.local_matrices[node_idx]
            except KeyError:
                # If local matrix not computed, compute it
                node = self.gltf.nodes[node_idx]
                translation = node.translation if node.translation else [0, 0, 0]
                rotation = node.rotation if node.rotation else [0, 0, 0, 1]
                scale = node.scale if node.scale else [1, 1, 1]
                self.local_matrices[node_idx] = compose_matrix(translation, rotation, scale)
                local = self.local_matrices[node_idx]
            parent_idx = self.node_to_parent.get(node_idx)
            if parent_idx is not None:
                parent_world = get_world_matrix(parent_idx)
                world = parent_world @ local
            else:
                world = local
            self.world_matrices[node_idx] = world
            return world
        
        for node_idx in self.joint_nodes:
            get_world_matrix(node_idx)
    
    def compute_final_skinning_matrices(self):
        """Compute world * inverseBind matrices for skinning."""
        self.final_skinning_matrices = {}
        for i, node_idx in enumerate(self.joint_nodes):
            world = self.world_matrices[node_idx]
            inv_bind = self.inverse_bind_matrices[i]
            self.final_skinning_matrices[node_idx] = world @ inv_bind
    
    def update(self):
        """Recompute all local and world matrices."""
        self.compute_local_matrices()
        self.compute_world_matrices()
        self.compute_final_skinning_matrices()
    
    def visualize(self):
        """Visualize the skeleton using pyrender."""
        self.update()  # Ensure transforms are up to date
        scene = pyrender.Scene()
    
    def save(self, filename="output.glb", path="/mnt/c/Users/janis/Documents/BlenderLiveView/"):
        """Save the modified GLTF to a file."""
        full_p = path + filename
        self.gltf.save_binary(full_p)
        print(f"Saved modified GLTF to {full_p}")

# %%
def forward_kinematics(joint_positions, parents, local_offsets):
    """
    Compute world-space joint positions from local offsets and parent indices.

    Args:
        joint_positions (dict): Output world-space joint positions.
        parents (dict): Mapping from joint index to parent index.
        local_offsets (dict): Local offset vectors for each joint.

    Returns:
        dict: Updated joint_positions with world-space coordinates.
    """
    joint_positions[0] = local_offsets[0]  # root
    for idx in sorted(local_offsets.keys()):
        if idx == 0:
            continue
        parent_idx = parents[idx]
        joint_positions[idx] = joint_positions[parent_idx] + local_offsets[idx]
    return joint_positions

# %%
import numpy as np

def fabrik(joint_positions, target, tolerance=1e-3, max_iter=10):
    """
    FABRIK inverse kinematics solver for a single bone chain.

    Args:
        joint_positions (list): List of joint positions as np.array([x, y, z]).
        target (np.array): Target position for the end effector.
        tolerance (float): Distance threshold for stopping.
        max_iter (int): Maximum number of iterations.

    Returns:
        list: New joint positions.
    """
    positions = joint_positions.copy()
    bone_lengths = [np.linalg.norm(positions[i+1] - positions[i]) for i in range(len(positions) - 1)]
    total_length = sum(bone_lengths)

    if np.linalg.norm(positions[0] - target) > total_length:
        # Target is unreachable: stretch toward it
        for i in range(len(positions) - 1):
            r = np.linalg.norm(target - positions[i])
            lambda_ = bone_lengths[i] / r
            positions[i+1] = (1 - lambda_) * positions[i] + lambda_ * target
        return positions

    for _ in range(max_iter):
        # Step 1: Forward reaching
        positions[-1] = target
        for i in reversed(range(len(positions) - 1)):
            r = np.linalg.norm(positions[i+1] - positions[i])
            lambda_ = bone_lengths[i] / r
            positions[i] = (1 - lambda_) * positions[i+1] + lambda_ * positions[i]

        # Step 2: Backward reaching
        positions[0] = joint_positions[0]
        for i in range(len(positions) - 1):
            r = np.linalg.norm(positions[i+1] - positions[i])
            lambda_ = bone_lengths[i] / r
            positions[i+1] = (1 - lambda_) * positions[i] + lambda_ * positions[i+1]

        # Convergence check
        if np.linalg.norm(positions[-1] - target) < tolerance:
            break

    return positions

# %%
def apply_pose_to_gltf(gltf, pose_dict):
    """
    Apply a pose to a GLTF model.

    Args:
        gltf (GLTF2): The GLTF model.
        pose_dict (dict): Dictionary of joint names and their transformations.
    """
    skeleton_helper = SkeletonHelper(gltf)
    skeleton_helper.apply_pose(pose_dict)
    skeleton_helper.update()
    skeleton_helper.save("output.glb")

# %%
def get_accessor_data(gltf, accessor_index):
    """
    Extracts the data for a given accessor from a glTF2 object into a NumPy array.
    
    Parameters:
        gltf (GLTF2): Loaded GLTF2 object (from pygltflib).
        accessor_index (int): Index of the accessor to extract.
    Returns:
        numpy.ndarray: Array of shape (count, components) with the accessor data.
    """
    import numpy as np
    
    # Retrieve accessor and bufferView objects
    try:
        accessor = gltf.accessors[accessor_index]
        buffer_view = gltf.bufferViews[accessor.bufferView]
        buffer = gltf.buffers[buffer_view.buffer]
    except IndexError:
        raise ValueError(f"Invalid accessor index: {accessor_index}")

    # Compute absolute byte offset within the buffer
    offset = (buffer_view.byteOffset or 0) + (accessor.byteOffset or 0)
    count = accessor.count

    # Determine number of components (SCALAR=1, VEC3=3, etc.)
    type_to_num = {
        "SCALAR": 1, "VEC2": 2, "VEC3": 3, "VEC4": 4,
        "MAT2": 4, "MAT3": 9, "MAT4": 16
    }
    num_components = type_to_num[accessor.type]

    # Map glTF componentType to numpy dtype
    comp_dtype_map = {
        5120: np.int8,
        5121: np.uint8,
        5122: np.int16,
        5123: np.uint16,
        5125: np.uint32,
        5126: np.float32
    }
    dtype = comp_dtype_map.get(accessor.componentType)
    if dtype is None:
        raise ValueError(f"Unsupported componentType: {accessor.componentType}")

    # Load the raw buffer bytes (handle embedded, external, or GLB)
    if buffer.uri:
        if buffer.uri.startswith("data:"):
            raw_bytes = gltf.decode_data_uri(buffer.uri)
        else:
            with open(buffer.uri, "rb") as f:
                raw_bytes = f.read()
    else:
        raw_bytes = gltf.binary_blob()

    # Determine byte stride (default = tightly packed)
    dtype_size = np.dtype(dtype).itemsize
    byte_stride = buffer_view.byteStride or (num_components * dtype_size)
    byte_length = count * byte_stride

    # Extract the relevant byte range for this accessor
    segment = raw_bytes[offset : offset + byte_length]

    # Use numpy to interpret as the dtype and reshape
    arr = np.frombuffer(segment, dtype=dtype)
    arr = arr.reshape((count, byte_stride // dtype_size))

    # Return only the first `num_components` columns (ignore padding)
    return arr[:, :num_components]

def get_joint_matrices(skeleton: SkeletonHelper):
    """Returns a list of final joint matrices: world * inverseBindMatrix."""
    ibms = skeleton.skin.inverseBindMatrices
    accessor = skeleton.gltf.accessors[ibms]
    ibm_data = get_accessor_data(skeleton.gltf)[ibms]  # shape (J, 4, 4)

    joint_matrices = []
    for joint_idx, ibm in zip(skeleton.joint_indices, ibm_data):
        joint_world = skeleton.world_matrices[joint_idx]
        joint_matrix = joint_world @ ibm
        joint_matrices.append(joint_matrix)
    return joint_matrices

# %%
def apply_skinning(skeleton: SkeletonHelper, joint_name) -> trimesh.Trimesh:
    gltf = skeleton.gltf
    skin = skeleton.skin
    mesh_node_idx = [idx for idx, node in enumerate(gltf.nodes) if node.mesh is not None][0]
    mesh_node = gltf.nodes[mesh_node_idx]
    mesh = gltf.meshes[mesh_node.mesh]

    primitive = gltf.meshes[skeleton.joint_name_to_idx[joint_name]].primitives[0]
    pos_accessor_idx = primitive.attributes.POSITION
    accessor_data = get_accessor_data(gltf, pos_accessor_idx)

    # Get base vertex positions
    position_accessor_idx = mesh.primitives[0].attributes.POSITION
    positions = accessor_data[position_accessor_idx]  # (N, 3)

    # Get joint indices and weights
    joints_accessor_idx = mesh.primitives[0].attributes.JOINTS_0
    weights_accessor_idx = mesh.primitives[0].attributes.WEIGHTS_0

    joints = accessor_data[joints_accessor_idx].astype(np.int32)  # (N, 4)
    weights = accessor_data[weights_accessor_idx]  # (N, 4)

    # Calculate final joint matrices: M_skin = world * inverseBindMatrix
    joint_matrices = get_joint_matrices(skeleton)  # list of 4x4 matrices, len = # joints

    # Perform skinning: v' = sum(w_i * M_i * v)
    skinned_vertices = []
    for i in range(len(positions)):
        pos_h = np.append(positions[i], 1.0)  # homogeneous coordinate
        skinned_pos = np.zeros(4)
        for j in range(4):
            joint_idx = joints[i][j]
            weight = weights[i][j]
            M = joint_matrices[joint_idx]
            skinned_pos += weight * (M @ pos_h)
        skinned_vertices.append(skinned_pos[:3])  # drop homogeneous w

    skinned_vertices = np.array(skinned_vertices)

    # Reuse indices from glTF
    indices_accessor_idx = mesh.primitives[0].indices
    faces = accessor_data[indices_accessor_idx].reshape(-1, 3)

    return trimesh.Trimesh(vertices=skinned_vertices, faces=faces, process=False)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial.transform import Rotation as R

def test_skeleton_helper():
    gltf = GLTF2().load("data/raw/human_base_mesh.glb")
    skeleton = SkeletonHelper(gltf)
    print("Joint names and indices:")
    skeleton.joint_name_to_idx = dict(sorted(skeleton.joint_name_to_idx.items()))
    for name, idx in skeleton.joint_name_to_idx.items():
        print(f"{name}: {idx}")
    #skeleton.set_joint_rotation_by_name("hips", [0, 0, 0, 1])
    skeleton.update()
    n_frames = 100
    elbow_joint_name = "DEF-foot.L"
    for frame in range(n_frames + 1):
        # Calculate the new rotation for the elbow joint
        rotation_angle = frame * (360 / n_frames)  # Rotating 360 degrees in n_frames steps
        r = R.from_euler('z', rotation_angle, degrees=True)
        quat = r.as_quat()

        # Apply the rotation to the elbow joint
        skeleton.set_joint_rotation_by_name(elbow_joint_name, quat)

        # Visualize the model at each frame
        print(f"Frame {frame + 1} - Elbow rotation: {rotation_angle}°")
        skeleton.save(filename=f"SkeletonHelperGLTF_{frame}.glb")

# %%
test_skeleton_helper()
# Out:
# Joint names and indices:
# DEF-breast.L: 197
# DEF-breast.R: 199
# DEF-foot.L: 90
# DEF-foot.R: 109
# DEF-forearm.L: 163
# DEF-forearm.L.001: 162
# DEF-forearm.R: 193
# DEF-forearm.R.001: 192
# DEF-hand.L: 161
# DEF-hand.R: 191
# DEF-pelvis.L: 44
# DEF-pelvis.R: 46
# DEF-shin.L: 92
# DEF-shin.L.001: 91
# DEF-shin.R: 111
# DEF-shin.R.001: 110
# DEF-shoulder.L: 149
# DEF-shoulder.R: 179
# DEF-spine: 36
# DEF-spine.001: 35
# DEF-spine.002: 34
# DEF-spine.003: 33
# DEF-spine.004: 32
# DEF-spine.005: 31
# DEF-spine.006: 30
# DEF-thigh.L: 94
# DEF-thigh.L.001: 93
# DEF-thigh.R: 113
# DEF-thigh.R.001: 112
# DEF-toe.L: 89
# DEF-toe.R: 108
# DEF-upper_arm.L: 165
# DEF-upper_arm.L.001: 164
# DEF-upper_arm.R: 195
# DEF-upper_arm.R.001: 194
# MCH-ROT-head: 130
# MCH-ROT-neck: 136
# MCH-STR-neck: 134
# MCH-WGT-chest: 207
# MCH-WGT-hips: 118
# MCH-foot_fk.L: 80
# MCH-foot_fk.R: 99
# MCH-foot_ik.parent.L: 235
# MCH-foot_ik.parent.R: 249
# MCH-foot_roll.L: 228
# MCH-foot_roll.R: 242
# MCH-foot_tweak.L: 51
# MCH-foot_tweak.R: 65
# MCH-forearm_ik.L: 155
# MCH-forearm_ik.R: 185
# MCH-forearm_tweak.L: 141
# MCH-forearm_tweak.L.001: 143
# MCH-forearm_tweak.R: 171
# MCH-forearm_tweak.R.001: 173
# MCH-hand_fk.L: 152
# MCH-hand_fk.R: 182
# MCH-hand_ik.parent.L: 216
# MCH-hand_ik.parent.R: 221
# MCH-hand_tweak.L: 138
# MCH-hand_tweak.R: 168
# MCH-heel.02_rock1.L: 231
# MCH-heel.02_rock1.R: 245
# MCH-heel.02_rock2.L: 232
# MCH-heel.02_rock2.R: 246
# MCH-heel.02_roll1.L: 229
# MCH-heel.02_roll1.R: 243
# MCH-heel.02_roll2.L: 230
# MCH-heel.02_roll2.R: 244
# MCH-pivot: 125
# MCH-shin_ik.L: 83
# MCH-shin_ik.R: 102
# MCH-shin_tweak.L: 54
# MCH-shin_tweak.L.001: 56
# MCH-shin_tweak.R: 68
# MCH-shin_tweak.R.001: 70
# MCH-spine: 120
# MCH-spine.001: 122
# MCH-spine.002: 211
# MCH-spine.003: 209
# MCH-spine.005: 133
# MCH-thigh_ik_swing.L: 85
# MCH-thigh_ik_swing.R: 104
# MCH-thigh_ik_target.L: 227
# MCH-thigh_ik_target.R: 241
# MCH-thigh_ik_target.parent.L: 237
# MCH-thigh_ik_target.parent.R: 251
# MCH-thigh_parent.L: 86
# MCH-thigh_parent.R: 105
# MCH-thigh_parent_widget.L: 58
# MCH-thigh_parent_widget.R: 72
# MCH-thigh_tweak.L: 88
# MCH-thigh_tweak.L.001: 60
# MCH-thigh_tweak.R: 107
# MCH-thigh_tweak.R.001: 74
# MCH-toe_fk.L: 78
# MCH-toe_fk.R: 97
# MCH-toe_ik_parent.L: 226
# MCH-toe_ik_parent.R: 240
# MCH-torso.parent: 213
# MCH-upper_arm_ik_swing.L: 157
# MCH-upper_arm_ik_swing.R: 187
# MCH-upper_arm_ik_target.L: 214
# MCH-upper_arm_ik_target.R: 219
# MCH-upper_arm_ik_target.parent.L: 218
# MCH-upper_arm_ik_target.parent.R: 223
# MCH-upper_arm_parent.L: 158
# MCH-upper_arm_parent.R: 188
# MCH-upper_arm_parent_widget.L: 145
# MCH-upper_arm_parent_widget.R: 175
# MCH-upper_arm_tweak.L: 160
# MCH-upper_arm_tweak.L.001: 147
# MCH-upper_arm_tweak.R: 190
# MCH-upper_arm_tweak.R.001: 177
# ORG-breast.L: 198
# ORG-breast.R: 200
# ORG-foot.L: 52
# ORG-foot.R: 66
# ORG-forearm.L: 144
# ORG-forearm.R: 174
# ORG-hand.L: 139
# ORG-hand.R: 169
# ORG-heel.02.L: 49
# ORG-heel.02.R: 63
# ORG-pelvis.L: 45
# ORG-pelvis.R: 47
# ORG-shin.L: 57
# ORG-shin.R: 71
# ORG-shoulder.L: 166
# ORG-shoulder.R: 196
# ORG-spine: 114
# ORG-spine.001: 116
# ORG-spine.002: 123
# ORG-spine.003: 205
# ORG-spine.004: 128
# ORG-spine.005: 127
# ORG-spine.006: 126
# ORG-thigh.L: 61
# ORG-thigh.R: 75
# ORG-toe.L: 48
# ORG-toe.R: 62
# ORG-upper_arm.L: 148
# ORG-upper_arm.R: 178
# VIS_thigh_ik_pole.L: 39
# VIS_thigh_ik_pole.R: 40
# VIS_upper_arm_ik_pole.L: 37
# VIS_upper_arm_ik_pole.R: 38
# breast.L: 201
# breast.R: 202
# chest: 43
# foot_fk.L: 79
# foot_fk.R: 98
# foot_heel_ik.L: 224
# foot_heel_ik.R: 238
# foot_ik.L: 234
# foot_ik.R: 248
# foot_spin_ik.L: 233
# foot_spin_ik.R: 247
# foot_tweak.L: 50
# foot_tweak.R: 64
# forearm_fk.L: 153
# forearm_fk.R: 183
# forearm_tweak.L: 140
# forearm_tweak.L.001: 142
# forearm_tweak.R: 170
# forearm_tweak.R.001: 172
# hand_fk.L: 151
# hand_fk.R: 181
# hand_ik.L: 215
# hand_ik.R: 220
# hand_tweak.L: 137
# hand_tweak.R: 167
# head: 129
# hips: 42
# neck: 135
# root: 41
# shin_fk.L: 81
# shin_fk.R: 100
# shin_tweak.L: 53
# shin_tweak.L.001: 55
# shin_tweak.R: 67
# shin_tweak.R.001: 69
# shoulder.L: 203
# shoulder.R: 204
# spine_fk: 119
# spine_fk.001: 121
# spine_fk.002: 210
# spine_fk.003: 208
# thigh_fk.L: 82
# thigh_fk.R: 101
# thigh_ik.L: 84
# thigh_ik.R: 103
# thigh_ik_target.L: 236
# thigh_ik_target.R: 250
# thigh_parent.L: 76
# thigh_parent.R: 95
# thigh_tweak.L: 87
# thigh_tweak.L.001: 59
# thigh_tweak.R: 106
# thigh_tweak.R.001: 73
# toe_fk.L: 77
# toe_fk.R: 96
# toe_ik.L: 225
# toe_ik.R: 239
# torso: 212
# tweak_spine: 115
# tweak_spine.001: 117
# tweak_spine.002: 124
# tweak_spine.003: 206
# tweak_spine.004: 131
# tweak_spine.005: 132
# upper_arm_fk.L: 154
# upper_arm_fk.R: 184
# upper_arm_ik.L: 156
# upper_arm_ik.R: 186
# upper_arm_ik_target.L: 217
# upper_arm_ik_target.R: 222
# upper_arm_parent.L: 150
# upper_arm_parent.R: 180
# upper_arm_tweak.L: 159
# upper_arm_tweak.L.001: 146
# upper_arm_tweak.R: 189
# upper_arm_tweak.R.001: 176
# Set joint 90 rotation to [0. 0. 0. 1.]
# Frame 1 - Elbow rotation: 0.0°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_0.glb
# Set joint 90 rotation to [0.         0.         0.03141076 0.99950656]
# Frame 2 - Elbow rotation: 3.6°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_1.glb
# Set joint 90 rotation to [0.         0.         0.06279052 0.99802673]
# Frame 3 - Elbow rotation: 7.2°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_2.glb
# Set joint 90 rotation to [0.         0.         0.09410831 0.99556196]
# Frame 4 - Elbow rotation: 10.8°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_3.glb
# Set joint 90 rotation to [0.         0.         0.12533323 0.9921147 ]
# Frame 5 - Elbow rotation: 14.4°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_4.glb
# Set joint 90 rotation to [0.         0.         0.15643447 0.98768834]
# Frame 6 - Elbow rotation: 18.0°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_5.glb
# Set joint 90 rotation to [0.         0.         0.18738131 0.98228725]
# Frame 7 - Elbow rotation: 21.6°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_6.glb
# Set joint 90 rotation to [0.         0.         0.21814324 0.97591676]
# Frame 8 - Elbow rotation: 25.2°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_7.glb
# Set joint 90 rotation to [0.         0.         0.24868989 0.96858316]
# Frame 9 - Elbow rotation: 28.8°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_8.glb
# Set joint 90 rotation to [0.         0.         0.27899111 0.96029369]
# Frame 10 - Elbow rotation: 32.4°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_9.glb
# Set joint 90 rotation to [0.         0.         0.30901699 0.95105652]
# Frame 11 - Elbow rotation: 36.0°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_10.glb
# Set joint 90 rotation to [0.         0.         0.33873792 0.94088077]
# Frame 12 - Elbow rotation: 39.6°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_11.glb
# Set joint 90 rotation to [0.         0.         0.36812455 0.92977649]
# Frame 13 - Elbow rotation: 43.2°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_12.glb
# Set joint 90 rotation to [0.         0.         0.39714789 0.91775463]
# Frame 14 - Elbow rotation: 46.800000000000004°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_13.glb
# Set joint 90 rotation to [0.         0.         0.42577929 0.90482705]
# Frame 15 - Elbow rotation: 50.4°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_14.glb
# Set joint 90 rotation to [0.         0.         0.4539905  0.89100652]
# Frame 16 - Elbow rotation: 54.0°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_15.glb
# Set joint 90 rotation to [0.         0.         0.48175367 0.87630668]
# Frame 17 - Elbow rotation: 57.6°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_16.glb
# Set joint 90 rotation to [0.         0.         0.50904142 0.86074203]
# Frame 18 - Elbow rotation: 61.2°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_17.glb
# Set joint 90 rotation to [0.         0.         0.53582679 0.84432793]
# Frame 19 - Elbow rotation: 64.8°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_18.glb
# Set joint 90 rotation to [0.         0.         0.56208338 0.82708057]
# Frame 20 - Elbow rotation: 68.4°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_19.glb
# Set joint 90 rotation to [0.         0.         0.58778525 0.80901699]
# Frame 21 - Elbow rotation: 72.0°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_20.glb
# Set joint 90 rotation to [0.         0.         0.61290705 0.79015501]
# Frame 22 - Elbow rotation: 75.60000000000001°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_21.glb
# Set joint 90 rotation to [0.         0.         0.63742399 0.77051324]
# Frame 23 - Elbow rotation: 79.2°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_22.glb
# Set joint 90 rotation to [0.         0.         0.66131187 0.75011107]
# Frame 24 - Elbow rotation: 82.8°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_23.glb
# Set joint 90 rotation to [0.         0.         0.68454711 0.72896863]
# Frame 25 - Elbow rotation: 86.4°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_24.glb
# Set joint 90 rotation to [0.         0.         0.70710678 0.70710678]
# Frame 26 - Elbow rotation: 90.0°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_25.glb
# Set joint 90 rotation to [0.         0.         0.72896863 0.68454711]
# Frame 27 - Elbow rotation: 93.60000000000001°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_26.glb
# Set joint 90 rotation to [0.         0.         0.75011107 0.66131187]
# Frame 28 - Elbow rotation: 97.2°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_27.glb
# Set joint 90 rotation to [0.         0.         0.77051324 0.63742399]
# Frame 29 - Elbow rotation: 100.8°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_28.glb
# Set joint 90 rotation to [0.         0.         0.79015501 0.61290705]
# Frame 30 - Elbow rotation: 104.4°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_29.glb
# Set joint 90 rotation to [0.         0.         0.80901699 0.58778525]
# Frame 31 - Elbow rotation: 108.0°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_30.glb
# Set joint 90 rotation to [0.         0.         0.82708057 0.56208338]
# Frame 32 - Elbow rotation: 111.60000000000001°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_31.glb
# Set joint 90 rotation to [0.         0.         0.84432793 0.53582679]
# Frame 33 - Elbow rotation: 115.2°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_32.glb
# Set joint 90 rotation to [0.         0.         0.86074203 0.50904142]
# Frame 34 - Elbow rotation: 118.8°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_33.glb
# Set joint 90 rotation to [0.         0.         0.87630668 0.48175367]
# Frame 35 - Elbow rotation: 122.4°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_34.glb
# Set joint 90 rotation to [0.         0.         0.89100652 0.4539905 ]
# Frame 36 - Elbow rotation: 126.0°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_35.glb
# Set joint 90 rotation to [0.         0.         0.90482705 0.42577929]
# Frame 37 - Elbow rotation: 129.6°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_36.glb
# Set joint 90 rotation to [0.         0.         0.91775463 0.39714789]
# Frame 38 - Elbow rotation: 133.20000000000002°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_37.glb
# Set joint 90 rotation to [0.         0.         0.92977649 0.36812455]
# Frame 39 - Elbow rotation: 136.8°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_38.glb
# Set joint 90 rotation to [0.         0.         0.94088077 0.33873792]
# Frame 40 - Elbow rotation: 140.4°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_39.glb
# Set joint 90 rotation to [0.         0.         0.95105652 0.30901699]
# Frame 41 - Elbow rotation: 144.0°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_40.glb
# Set joint 90 rotation to [0.         0.         0.96029369 0.27899111]
# Frame 42 - Elbow rotation: 147.6°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_41.glb
# Set joint 90 rotation to [0.         0.         0.96858316 0.24868989]
# Frame 43 - Elbow rotation: 151.20000000000002°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_42.glb
# Set joint 90 rotation to [0.         0.         0.97591676 0.21814324]
# Frame 44 - Elbow rotation: 154.8°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_43.glb
# Set joint 90 rotation to [0.         0.         0.98228725 0.18738131]
# Frame 45 - Elbow rotation: 158.4°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_44.glb
# Set joint 90 rotation to [0.         0.         0.98768834 0.15643447]
# Frame 46 - Elbow rotation: 162.0°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_45.glb
# Set joint 90 rotation to [0.         0.         0.9921147  0.12533323]
# Frame 47 - Elbow rotation: 165.6°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_46.glb
# Set joint 90 rotation to [0.         0.         0.99556196 0.09410831]
# Frame 48 - Elbow rotation: 169.20000000000002°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_47.glb
# Set joint 90 rotation to [0.         0.         0.99802673 0.06279052]
# Frame 49 - Elbow rotation: 172.8°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_48.glb
# Set joint 90 rotation to [0.         0.         0.99950656 0.03141076]
# Frame 50 - Elbow rotation: 176.4°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_49.glb
# Set joint 90 rotation to [0.000000e+00 0.000000e+00 1.000000e+00 6.123234e-17]
# Frame 51 - Elbow rotation: 180.0°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_50.glb
# Set joint 90 rotation to [ 0.          0.          0.99950656 -0.03141076]
# Frame 52 - Elbow rotation: 183.6°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_51.glb
# Set joint 90 rotation to [ 0.          0.          0.99802673 -0.06279052]
# Frame 53 - Elbow rotation: 187.20000000000002°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_52.glb
# Set joint 90 rotation to [ 0.          0.          0.99556196 -0.09410831]
# Frame 54 - Elbow rotation: 190.8°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_53.glb
# Set joint 90 rotation to [ 0.          0.          0.9921147  -0.12533323]
# Frame 55 - Elbow rotation: 194.4°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_54.glb
# Set joint 90 rotation to [ 0.          0.          0.98768834 -0.15643447]
# Frame 56 - Elbow rotation: 198.0°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_55.glb
# Set joint 90 rotation to [ 0.          0.          0.98228725 -0.18738131]
# Frame 57 - Elbow rotation: 201.6°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_56.glb
# Set joint 90 rotation to [ 0.          0.          0.97591676 -0.21814324]
# Frame 58 - Elbow rotation: 205.20000000000002°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_57.glb
# Set joint 90 rotation to [ 0.          0.          0.96858316 -0.24868989]
# Frame 59 - Elbow rotation: 208.8°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_58.glb
# Set joint 90 rotation to [ 0.          0.          0.96029369 -0.27899111]
# Frame 60 - Elbow rotation: 212.4°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_59.glb
# Set joint 90 rotation to [ 0.          0.          0.95105652 -0.30901699]
# Frame 61 - Elbow rotation: 216.0°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_60.glb
# Set joint 90 rotation to [ 0.          0.          0.94088077 -0.33873792]
# Frame 62 - Elbow rotation: 219.6°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_61.glb
# Set joint 90 rotation to [ 0.          0.          0.92977649 -0.36812455]
# Frame 63 - Elbow rotation: 223.20000000000002°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_62.glb
# Set joint 90 rotation to [ 0.          0.          0.91775463 -0.39714789]
# Frame 64 - Elbow rotation: 226.8°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_63.glb
# Set joint 90 rotation to [ 0.          0.          0.90482705 -0.42577929]
# Frame 65 - Elbow rotation: 230.4°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_64.glb
# Set joint 90 rotation to [ 0.          0.          0.89100652 -0.4539905 ]
# Frame 66 - Elbow rotation: 234.0°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_65.glb
# Set joint 90 rotation to [ 0.          0.          0.87630668 -0.48175367]
# Frame 67 - Elbow rotation: 237.6°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_66.glb
# Set joint 90 rotation to [ 0.          0.          0.86074203 -0.50904142]
# Frame 68 - Elbow rotation: 241.20000000000002°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_67.glb
# Set joint 90 rotation to [ 0.          0.          0.84432793 -0.53582679]
# Frame 69 - Elbow rotation: 244.8°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_68.glb
# Set joint 90 rotation to [ 0.          0.          0.82708057 -0.56208338]
# Frame 70 - Elbow rotation: 248.4°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_69.glb
# Set joint 90 rotation to [ 0.          0.          0.80901699 -0.58778525]
# Frame 71 - Elbow rotation: 252.0°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_70.glb
# Set joint 90 rotation to [ 0.          0.          0.79015501 -0.61290705]
# Frame 72 - Elbow rotation: 255.6°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_71.glb
# Set joint 90 rotation to [ 0.          0.          0.77051324 -0.63742399]
# Frame 73 - Elbow rotation: 259.2°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_72.glb
# Set joint 90 rotation to [ 0.          0.          0.75011107 -0.66131187]
# Frame 74 - Elbow rotation: 262.8°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_73.glb
# Set joint 90 rotation to [ 0.          0.          0.72896863 -0.68454711]
# Frame 75 - Elbow rotation: 266.40000000000003°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_74.glb
# Set joint 90 rotation to [ 0.          0.          0.70710678 -0.70710678]
# Frame 76 - Elbow rotation: 270.0°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_75.glb
# Set joint 90 rotation to [ 0.          0.          0.68454711 -0.72896863]
# Frame 77 - Elbow rotation: 273.6°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_76.glb
# Set joint 90 rotation to [ 0.          0.          0.66131187 -0.75011107]
# Frame 78 - Elbow rotation: 277.2°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_77.glb
# Set joint 90 rotation to [ 0.          0.          0.63742399 -0.77051324]
# Frame 79 - Elbow rotation: 280.8°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_78.glb
# Set joint 90 rotation to [ 0.          0.          0.61290705 -0.79015501]
# Frame 80 - Elbow rotation: 284.40000000000003°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_79.glb
# Set joint 90 rotation to [ 0.          0.          0.58778525 -0.80901699]
# Frame 81 - Elbow rotation: 288.0°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_80.glb
# Set joint 90 rotation to [ 0.          0.          0.56208338 -0.82708057]
# Frame 82 - Elbow rotation: 291.6°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_81.glb
# Set joint 90 rotation to [ 0.          0.          0.53582679 -0.84432793]
# Frame 83 - Elbow rotation: 295.2°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_82.glb
# Set joint 90 rotation to [ 0.          0.          0.50904142 -0.86074203]
# Frame 84 - Elbow rotation: 298.8°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_83.glb
# Set joint 90 rotation to [ 0.          0.          0.48175367 -0.87630668]
# Frame 85 - Elbow rotation: 302.40000000000003°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_84.glb
# Set joint 90 rotation to [ 0.          0.          0.4539905  -0.89100652]
# Frame 86 - Elbow rotation: 306.0°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_85.glb
# Set joint 90 rotation to [ 0.          0.          0.42577929 -0.90482705]
# Frame 87 - Elbow rotation: 309.6°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_86.glb
# Set joint 90 rotation to [ 0.          0.          0.39714789 -0.91775463]
# Frame 88 - Elbow rotation: 313.2°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_87.glb
# Set joint 90 rotation to [ 0.          0.          0.36812455 -0.92977649]
# Frame 89 - Elbow rotation: 316.8°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_88.glb
# Set joint 90 rotation to [ 0.          0.          0.33873792 -0.94088077]
# Frame 90 - Elbow rotation: 320.40000000000003°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_89.glb
# Set joint 90 rotation to [ 0.          0.          0.30901699 -0.95105652]
# Frame 91 - Elbow rotation: 324.0°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_90.glb
# Set joint 90 rotation to [ 0.          0.          0.27899111 -0.96029369]
# Frame 92 - Elbow rotation: 327.6°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_91.glb
# Set joint 90 rotation to [ 0.          0.          0.24868989 -0.96858316]
# Frame 93 - Elbow rotation: 331.2°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_92.glb
# Set joint 90 rotation to [ 0.          0.          0.21814324 -0.97591676]
# Frame 94 - Elbow rotation: 334.8°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_93.glb
# Set joint 90 rotation to [ 0.          0.          0.18738131 -0.98228725]
# Frame 95 - Elbow rotation: 338.40000000000003°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_94.glb
# Set joint 90 rotation to [ 0.          0.          0.15643447 -0.98768834]
# Frame 96 - Elbow rotation: 342.0°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_95.glb
# Set joint 90 rotation to [ 0.          0.          0.12533323 -0.9921147 ]
# Frame 97 - Elbow rotation: 345.6°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_96.glb
# Set joint 90 rotation to [ 0.          0.          0.09410831 -0.99556196]
# Frame 98 - Elbow rotation: 349.2°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_97.glb
# Set joint 90 rotation to [ 0.          0.          0.06279052 -0.99802673]
# Frame 99 - Elbow rotation: 352.8°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_98.glb
# Set joint 90 rotation to [ 0.          0.          0.03141076 -0.99950656]
# Frame 100 - Elbow rotation: 356.40000000000003°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_99.glb
# Set joint 90 rotation to [ 0.0000000e+00  0.0000000e+00  1.2246468e-16 -1.0000000e+00]
# Frame 101 - Elbow rotation: 360.0°
# Saved modified GLTF to /mnt/c/Users/janis/Documents/BlenderLiveView/SkeletonHelperGLTF_100.glb

# %%
def test_skeleton_helper2():
    pass

# %%
def test_skeleton_helper3():
    pass
